# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "対照":[4.17, 5.58, 5.18, 6.11, 4.50, 4.61, 5.17, 4.53, 5.33, 5.14],
        "処理A":[4.81, 4.17, 4.41, 3.59, 5.87, 3.83, 6.03, 4.89, 4.32, 4.69],
        "処理B":[6.31, 5.12, 5.54, 5.5, 5.37, 5.29, 4.92, 6.15, 5.8, 5.26]
    }
)

# %%
df
# Out:
#      対照   処理A   処理B
# 0  4.17  4.81  6.31
# 1  5.58  4.17  5.12
# 2  5.18  4.41  5.54
# 3  6.11  3.59  5.50
# 4  4.50  5.87  5.37
# 5  4.61  3.83  5.29
# 6  5.17  6.03  4.92
# 7  4.53  4.89  6.15
# 8  5.33  4.32  5.80
# 9  5.14  4.69  5.26

# %%
D1 = ((df**2).sum().sum() - ((df.sum())**2).sum() / len(df))
# Out:
# 786.3182999999999

# %%
((df.sum())**2).sum()
# Out:
# 7758.262099999999
