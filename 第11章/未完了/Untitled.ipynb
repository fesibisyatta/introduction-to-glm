# %%
import pandas as pd
import numpy as np

# %%
url = "https://gksmyth.github.io/ozdasl/oz/stroke.txt"
df = pd.read_csv(url, sep="\t")  # 区切りがタブっぽいので \t を指定
# 使用項目の選定
usecols = [
    "Subject",
    "Group",
    "Bart1",
    "Bart2",
    "Bart3",
    "Bart4",
    "Bart5",
    "Bart6",
    "Bart7",
    "Bart8",
]
df = df[usecols]

# %%
df
# Out:
#    Subject Group  Bart1  Bart2  Bart3  Bart4  Bart5  Bart6  Bart7  Bart8
# 0        I     E     45     45     45     45     80     80     80     90
# 1       II     E     20     25     25     25     30     35     30     50
# 2      III     E     50     50     55     70     70     75     90     90
# 3       IV     E     25     25     35     40     60     60     70     80
# 4        V     E    100    100    100    100    100    100    100    100
# 5       VI     E     20     20     30     50     50     60     85     95
# 6      VII     E     30     35     35     40     50     60     75     85
# 7     VIII     E     30     35     45     50     55     65     65     70
# 8        1     F     40     55     60     70     80     85     90     90
# 9        2     F     65     65     70     70     80     80     80     80
# 10       3     F     30     30     40     45     65     85     85     85
# 11       4     F     25     35     35     35     40     45     45     45
# ...
