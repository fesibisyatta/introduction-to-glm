# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.genmod.generalized_estimating_equations import GEE
from statsmodels.genmod.families import Gaussian, Binomial
from statsmodels.genmod.cov_struct import Exchangeable, Independence, Autoregressive, Unstructured

# %%
url = "https://gksmyth.github.io/ozdasl/oz/stroke.txt"
df = pd.read_csv(url, sep="\t")  # 区切りがタブっぽいので \t を指定

usecols = ['Subject', 'Group', 'Bart1', 'Bart2', 'Bart3', 'Bart4', 'Bart5', 'Bart6', 'Bart7', 'Bart8']
df = df[usecols]

# %%
df.head()
# Out:
#   Subject Group  Bart1  Bart2  Bart3  Bart4  Bart5  Bart6  Bart7  Bart8
# 0       I     E     45     45     45     45     80     80     80     90
# 1      II     E     20     25     25     25     30     35     30     50
# 2     III     E     50     50     55     70     70     75     90     90
# 3      IV     E     25     25     35     40     60     60     70     80
# 4       V     E    100    100    100    100    100    100    100    100

# %%
# Groupをダミー変数にする（alpha）
dummy = pd.get_dummies(df["Group"], columns=["Group"]).astype(int)
dummy = dummy.loc[np.repeat(dummy.index, 8)].reset_index(drop=True)

# 分散分析しやすいようにデータ加工
X = df.drop(["Subject", "Group"], axis = 1).stack().reset_index().drop(["level_0"], axis = 1).rename(columns = {"level_1":"week", 0:"Berthel_Score"})
X = pd.concat([dummy,X],axis = 1)

# %%
X.head()
# Out:
#    E  F  G   week  Berthel_Score
# 0  1  0  0  Bart1             45
# 1  1  0  0  Bart2             45
# 2  1  0  0  Bart3             45
# 3  1  0  0  Bart4             45
# 4  1  0  0  Bart5             80

# %%
# Groupをダミー変数にする（alpha）
dummy = pd.get_dummies(df["Group"], columns=["Group"]).astype(int)
dummy = dummy.loc[np.repeat(dummy.index, 8)].reset_index(drop=True)

# 分散分析しやすいようにデータ加工
X = df.drop(["Subject", "Group"], axis = 1).stack().reset_index().drop(["level_0"], axis = 1).rename(columns = {"level_1":"week", 0:"Berthel_Score"})
X = pd.concat([dummy,X],axis = 1)

# weekはそのまま数字を入れる（beta）
X["week"] = X["week"].str[4:].astype(int)
X["beta1_week"] = X["E"] * X["week"]
X["beta2_week"] = X["F"] * X["week"]
X["beta3_week"] = X["G"] * X["week"]

# 推定対象はalpha2, alpha3ではなく、alpha2 - alpha1, alpha3 - alpha1 とみなすので、
# 基準のとなるEはすべて１とする
# beta1, beta2, beta3 についても同様
X["E"] = 1
X["beta1_week"] = [1, 2, 3,4 ,5 , 6, 7, 8]*24

# 目的変数と説明変数に分ける
y = X["Berthel_Score"]
X["ids"] = np.repeat(np.arange(24), 8)
#X = X[["E", "F", "G", "beta1_week", "beta2_week", "beta3_week"]].values

# %%
X
# Out:
#      E  F  G  week  Berthel_Score  beta1_week  beta2_week  beta3_week  ids
# 0    1  0  0     1             45           1           0           0    0
# 1    1  0  0     2             45           2           0           0    0
# 2    1  0  0     3             45           3           0           0    0
# 3    1  0  0     4             45           4           0           0    0
# 4    1  0  0     5             80           5           0           0    0
# ..  .. .. ..   ...            ...         ...         ...         ...  ...
# 187  1  0  1     4             35           4           0           4   23
# 188  1  0  1     5             40           5           0           5   23
# 189  1  0  1     6             50           6           0           6   23
# 190  1  0  1     7             65           7           0           7   23
# 191  1  0  1     8             65           8           0           8   23
#
# [192 rows x 9 columns]

# %% [markdown]
# ## 独立の場合

# %%
# GEE（独立相関）
model = GEE(
    endog = y,
    exog = X[["E", "F", "G", "beta1_week", "beta2_week", "beta3_week"]].values, 
    groups=X["ids"],
    family=Gaussian(),
    cov_struct=Independence()
)
result = model.fit()

print(result.summary())
# 係数・標準誤差
print("params:\n", result.params)
print("bse:\n", result.bse)
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:               Berthel_Score   No. Observations:                  192
# Model:                                 GEE   No. clusters:                       24
# Method:                        Generalized   Min. cluster size:                   8
#                       Estimating Equations   Max. cluster size:                   8
# Family:                           Gaussian   Mean cluster size:                 8.0
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Sun, 24 Aug 2025   Scale:                         439.293
# Covariance type:                    robust   Time:                         09:36:13
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.8214     10.176      2.931      0.003       9.877      49.765
# x1             3.3482     11.633      0.288      0.773     -19.453      26.149
# x2            -0.0223     10.896     -0.002      0.998     -21.378      21.333
# x3             6.3244      1.131      5.590      0.000       4.107       8.542
# x4            -1.9940      1.478     -1.349      0.177      -4.890       0.902
# x5            -2.6860      1.470     -1.827      0.068      -5.567       0.195
# ==============================================================================
# Skew:                          0.4907   Kurtosis:                       0.1523
# Centered skew:                -0.0361   Centered kurtosis:              0.4403
# ==============================================================================
# params:
#  const    29.821429
# x1        3.348214
# x2       -0.022321
# x3        6.324405
# x4       -1.994048
# x5       -2.686012
# dtype: float64
# bse:
#  const    10.175732
# x1       11.633330
# x2       10.895850
# x3        1.131478
# x4        1.477623
# x5        1.470099
# dtype: float64

# %% [markdown]
# ## 交換可能（等相関）の場合

# %%
# GEE（独立相関）
model = GEE(
    endog = y,
    exog = X[["E", "F", "G", "beta1_week", "beta2_week", "beta3_week"]].values, 
    groups=X["ids"],
    family=Gaussian(),
    cov_struct=Exchangeable()
)
result = model.fit()

print(result.summary())
# 係数・標準誤差
print("params:\n", result.params)
print("bse:\n", result.bse)
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:               Berthel_Score   No. Observations:                  192
# Model:                                 GEE   No. clusters:                       24
# Method:                        Generalized   Min. cluster size:                   8
#                       Estimating Equations   Max. cluster size:                   8
# Family:                           Gaussian   Mean cluster size:                 8.0
# Dependence structure:         Exchangeable   Num. iterations:                     2
# Date:                     Sun, 24 Aug 2025   Scale:                         439.293
# Covariance type:                    robust   Time:                         09:36:13
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         29.8214     10.176      2.931      0.003       9.877      49.765
# x1             3.3482     11.633      0.288      0.773     -19.453      26.149
# x2            -0.0223     10.896     -0.002      0.998     -21.378      21.333
# x3             6.3244      1.131      5.590      0.000       4.107       8.542
# x4            -1.9940      1.478     -1.349      0.177      -4.890       0.902
# x5            -2.6860      1.470     -1.827      0.068      -5.567       0.195
# ==============================================================================
# Skew:                          0.4907   Kurtosis:                       0.1523
# Centered skew:                -0.0361   Centered kurtosis:              0.4403
# ==============================================================================
# params:
#  const    29.821429
# x1        3.348214
# x2       -0.022321
# x3        6.324405
# x4       -1.994048
# x5       -2.686012
# dtype: float64
# bse:
#  const    10.175732
# x1       11.633330
# x2       10.895850
# x3        1.131478
# x4        1.477623
# x5        1.470099
# dtype: float64

# %% [markdown]
# ## 自己回帰の場合

# %%
# GEE（独立相関）
model = GEE(
    endog = y.values,
    exog = X[["E", "F", "G", "beta1_week", "beta2_week", "beta3_week"]].values, 
    groups=X["ids"].values,
    time = X["week"].values,
    family=Gaussian(),
    cov_struct=Autoregressive()
)
result = model.fit()

print(result.summary())
# 係数・標準誤差
print("params:\n", result.params)
print("bse:\n", result.bse)
# Out:
# /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/genmod/cov_struct.py:796: FutureWarning: grid=True will become default in a future version
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 10
#       1 # GEE（独立相関）
#       2 model = GEE(
#       3     endog = y.values,
#       4     exog = X[["E", "F", "G", "beta1_week", "beta2_week", "beta3_week"]].values,
#    (...)      8     cov_struct=Autoregressive()
#       9 )
# ---> 10 result = model.fit()
#      12 print(result.summary())
#      13 # 係数・標準誤差
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/genmod/generalized_estimating_equations.py:1296, in GEE.fit(self, maxiter, ctol, start_params, params_niter, first_dep_update, cov_type, ddof_scale, scaling_factor, scale)
#    1293     # Update the dependence structure
#    1294     if (self.update_dep and (itr % params_niter) == 0
#    1295             and (itr >= first_dep_update)):
# -> 1296         self._update_assoc(mean_params)
#    1297         num_assoc_updates += 1
#    1299 if del_params >= ctol:
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/genmod/generalized_estimating_equations.py:1635, in GEE._update_assoc(self, params)
#    1630 def _update_assoc(self, params):
#    1631     """
#    1632     Update the association parameters
#    1633     """
# -> 1635     self.cov_struct.update(params)
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/genmod/cov_struct.py:818, in Autoregressive.update(self, params)
#     816     self._update_grid(params)
#     817 else:
# --> 818     self._update_nogrid(params)
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/genmod/cov_struct.py:913, in Autoregressive._update_nogrid(self, params)
#     911     f_rgt = fitfunc(b_rgt)
#     912     if b_rgt > 1. - 1e-6:
# --> 913         raise ValueError(
#     914             "Autoregressive: unable to find right bracket")
#     916 from scipy.optimize import brent
#     917 self.dep_params = brent(fitfunc, brack=[b_lft, b_ctr, b_rgt])
#
# ValueError: Autoregressive: unable to find right bracket

# %% [markdown]
# ## 無構造の場合

# %%
# GEE（独立相関）
model = GEE(
    endog = y.values,
    exog = X[["E", "F", "G", "beta1_week", "beta2_week", "beta3_week"]].values, 
    groups=X["ids"].values,
    time = X["week"].values,
    family=Gaussian(),
    cov_struct=Unstructured()
)
result = model.fit()

print(result.summary())
# 係数・標準誤差
print("params:\n", result.params)
print("bse:\n", result.bse)
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                           y   No. Observations:                  192
# Model:                                 GEE   No. clusters:                       24
# Method:                        Generalized   Min. cluster size:                   8
#                       Estimating Equations   Max. cluster size:                   8
# Family:                           Gaussian   Mean cluster size:                 8.0
# Dependence structure:         Unstructured   Num. iterations:                    28
# Date:                     Sun, 24 Aug 2025   Scale:                         478.232
# Covariance type:                    robust   Time:                         09:43:10
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.4308     10.571      2.879      0.004       9.712      51.149
# x1             5.4245     11.356      0.478      0.633     -16.832      27.681
# x2            -1.5291     10.979     -0.139      0.889     -23.047      19.988
# x3             7.2950      1.272      5.733      0.000       4.801       9.789
# x4            -4.5026      1.439     -3.129      0.002      -7.323      -1.683
# x5            -4.9390      1.411     -3.500      0.000      -7.705      -2.173
# ==============================================================================
# Skew:                          0.5395   Kurtosis:                       0.1258
# Centered skew:                -0.2434   Centered kurtosis:              1.3742
# ==============================================================================
# params:
#  [30.43078619  5.42454728 -1.52907183  7.29501202 -4.50259805 -4.93898149]
# bse:
#  [10.57078739 11.35567084 10.97850918  1.27240488  1.43879485  1.41110029]
# /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/genmod/cov_struct.py:301: RuntimeWarning: invalid value encountered in divide
#   cov /= np.outer(sd, sd)

# %% [markdown]
# ## 混合モデルの場合

# %%
X
# Out:
#      E  F  G  week  Berthel_Score  beta1_week  beta2_week  beta3_week  ids
# 0    1  0  0     1             45           1           0           0    0
# 1    1  0  0     2             45           2           0           0    0
# 2    1  0  0     3             45           3           0           0    0
# 3    1  0  0     4             45           4           0           0    0
# 4    1  0  0     5             80           5           0           0    0
# ..  .. .. ..   ...            ...         ...         ...         ...  ...
# 187  1  0  1     4             35           4           0           4   23
# 188  1  0  1     5             40           5           0           5   23
# 189  1  0  1     6             50           6           0           6   23
# 190  1  0  1     7             65           7           0           7   23
# 191  1  0  1     8             65           8           0           8   23
#
# [192 rows x 9 columns]

# %%
y
# Out:
# 0      45
# 1      45
# 2      45
# 3      45
# 4      80
#        ..
# 187    35
# 188    40
# 189    50
# 190    65
# 191    65
# Name: Berthel_Score, Length: 192, dtype: int64

# %%
# モデル: y ~ x1 + x2 + (1 | group)
model = sm.MixedLM.from_formula(
    "Berthel_Score ~ E + F + G + beta1_week + beta2_week + beta3_week", 
    groups="ids", 
    re_formula="1",   # ランダム効果の式
    data = X
)
result = model.fit(reml = False)  # REML推定（reml=FalseならML推定）
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[20], line 8
#       1 # モデル: y ~ x1 + x2 + (1 | group)
#       2 model = sm.MixedLM.from_formula(
#       3     "Berthel_Score ~ E + F + G + beta1_week + beta2_week + beta3_week",
#       4     groups="ids",
#       5     re_formula="1",   # ランダム効果の式
#       6     data = X
#       7 )
# ----> 8 result = model.fit(reml=False)  # REML推定（reml=FalseならML推定）
#       9 print(result.summary())
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2191, in MixedLM.fit(self, start_params, reml, niter_sa, do_cg, fe_pen, cov_pen, free, full_output, method, **fit_kwargs)
#    2189 # Try optimizing one or more times
#    2190 for j in range(len(method)):
# -> 2191     rslt = super().fit(start_params=packed,
#    2192                        skip_hessian=True,
#    2193                        method=method[j],
#    2194                        **fit_kwargs)
#    2195     if rslt.mle_retvals['converged']:
#    2196         break
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/base/model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/base/optimizer.py:245, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     242     fit_funcs.update(extra_fit_funcs)
#     244 func = fit_funcs[method]
# --> 245 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     246                      disp=disp, maxiter=maxiter, callback=callback,
#     247                      retall=retall, full_output=full_output,
#     248                      hess=hessian)
#     250 optim_settings = {'optimizer': method, 'start_params': start_params,
#     251                   'maxiter': maxiter, 'full_output': full_output,
#     252                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     253                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     254 optim_settings.update(kwargs)
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/base/optimizer.py:540, in _fit_bfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     538 norm = kwargs.setdefault('norm', np.inf)
#     539 epsilon = kwargs.setdefault('epsilon', 1.4901161193847656e-08)
# --> 540 retvals = optimize.fmin_bfgs(f, start_params, score, args=fargs,
#     541                              gtol=gtol, norm=norm, epsilon=epsilon,
#     542                              maxiter=maxiter, full_output=full_output,
#     543                              disp=disp, retall=retall, callback=callback)
#     544 if full_output:
#     545     if not retall:
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1313, in fmin_bfgs(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback, xrtol, c1, c2, hess_inv0)
#    1301 opts = {'gtol': gtol,
#    1302         'norm': norm,
#    1303         'eps': epsilon,
#    (...)   1309         'c2': c2,
#    1310         'hess_inv0': hess_inv0}
#    1312 callback = _wrap_callback(callback)
# -> 1313 res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#    1315 if full_output:
#    1316     retlist = (res['x'], res['fun'], res['jac'], res['hess_inv'],
#    1317                res['nfev'], res['njev'], res['status'])
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/scipy/optimize/_optimize.py:1393, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1390 if maxiter is None:
#    1391     maxiter = len(x0) * 200
# -> 1393 sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1394                               finite_diff_rel_step=finite_diff_rel_step)
#    1396 f = sf.fun
#    1397 myfprime = sf.grad
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/scipy/optimize/_optimize.py:291, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     287     bounds = (-np.inf, np.inf)
#     289 # ScalarFunction caches. Reuse of fun(x) during grad
#     290 # calculation reduces overall function evaluations.
# --> 291 sf = ScalarFunction(fun, x0, args, grad, hess,
#     292                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     294 return sf
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:223, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     220     finite_diff_options["as_linear_operator"] = True
#     222 # Initial function evaluation
# --> 223 self._update_fun()
#     225 # Initial gradient evaluation
#     226 self._wrapped_grad, self._ngev = _wrapper_grad(
#     227     grad,
#     228     fun=self._wrapped_fun,
#     229     args=args,
#     230     finite_diff_options=finite_diff_options
#     231 )
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/base/model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1498, in MixedLM.loglike(self, params, profile_fe)
#    1496 # Move to the profile set
#    1497 if profile_fe:
# -> 1498     fe_params, sing = self.get_fe_params(cov_re, vcomp)
#    1499     if sing:
#    1500         self._cov_sing += 1
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1345, in MixedLM.get_fe_params(self, cov_re, vcomp, tol)
#    1343     fe_params = np.dot(np.linalg.pinv(xtxy[:, 0:-1]), xtxy[:, -1])
#    1344 else:
# -> 1345     fe_params = np.linalg.solve(xtxy[:, 0:-1], xtxy[:, -1])
#    1347 return fe_params, sing
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/numpy/linalg/linalg.py:409, in solve(a, b)
#     407 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     408 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 409 r = gufunc(a, b, signature=signature, extobj=extobj)
#     411 return wrap(r.astype(result_t, copy=False))
#
# File /opt/anaconda3/envs/math_markething/lib/python3.12/site-packages/numpy/linalg/linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
